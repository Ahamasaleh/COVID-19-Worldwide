# %%
############################## COVID-19 Deathrate Predection Model #######################
from __future__ import absolute_import, division, print_function
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# load dataset
df = pd.read_csv("COVID19-PCA.csv")
data=df.to_numpy()

# split into features (X) and target (Y)
X = data[:,1:]
Y = data[:,0]

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3,random_state = 0)

 
# Initialising the NN Model

model = Sequential()
model.add(Dense(90, activation = 'relu', input_dim = 9))
model.add(Dense(units = 1, activation='linear'))


model.compile(optimizer = 'adam', loss = 'mae', metrics=['cosine_proximity'])

# Fitting the NN to the Training set
history= model.fit(X_train, y_train, batch_size = 10, epochs = 40)
test_loss, test_acc=model.evaluate(X_test,y_test)
print('Test Accuracy:', test_acc,'\n')
# Out:
# Epoch 1/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1489 - cosine_proximity: -0.0184
# Epoch 2/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0882 - cosine_proximity: -0.1255
# Epoch 3/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0623 - cosine_proximity: -0.0436
# Epoch 4/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0441 - cosine_proximity: 0.0579
# Epoch 5/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0310 - cosine_proximity: -0.1360
# Epoch 6/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0305 - cosine_proximity: -0.0135
# Epoch 7/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0191 - cosine_proximity: 0.0122
# Epoch 8/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0127 - cosine_proximity: 0.0406
# Epoch 9/40
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0096 - cosine_proximity: -4.3479e-04
# ...

# %%
############## 2nd, first 5 variables on TensorFlow.

X = data[:,1:6]  #features
Y = data[:,0]   #target
  
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.4,random_state = 0)
 
# Initialising the NN Model
model = Sequential()
model.add(Dense(50, activation = 'relu', input_dim = 5))
model.add(Dense(units = 1, activation="linear"))
model.compile(optimizer = 'adam', loss = 'mean_absolute_error', metrics=['cosine_proximity'])

# Fitting the NN to the Training set
history= model.fit(X_train, y_train, batch_size = 10, epochs = 10)

test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test Accuracy:', test_acc, '\n')
# Out:
# Epoch 1/10
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1367 - cosine_proximity: 0.1005
# Epoch 2/10
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0801 - cosine_proximity: -0.0128
# Epoch 3/10
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0445 - cosine_proximity: -0.0656
# Epoch 4/10
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0290 - cosine_proximity: 0.0704
# Epoch 5/10
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0164 - cosine_proximity: -0.0048
# Epoch 6/10
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0117 - cosine_proximity: -0.0656
# Epoch 7/10
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0088 - cosine_proximity: 0.0473
# Epoch 8/10
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0125 - cosine_proximity: 0.1155
# Epoch 9/10
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0129 - cosine_proximity: 0.0499
# ...

# %%
# 3rd, only first 2 variables on TensorFlow.

X = data[:,1:3]  # features
Y = data[:,0]    # target

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3,random_state = 0)
 
# Initialising the NN Model
model = Sequential()
model.add(Dense(10, activation = 'relu', input_dim = 2))
model.add(Dense(units = 1, activation="linear"))
model.compile(optimizer = 'adam', loss = 'mse', metrics=['cosine_proximity'])

# Fitting the NN to the Training set
history= model.fit(X_train, y_train, batch_size = 10, epochs =10)
y_pred = model.predict(X_test)
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test Accuracy:', test_acc, '\n')
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 53.9099 - cosine_proximity: 0.8081
# Epoch 2/10
# 16/16 [==============================] - 0s 970us/step - loss: 45.3564 - cosine_proximity: 0.8081
# Epoch 3/10
# 16/16 [==============================] - 0s 918us/step - loss: 37.9871 - cosine_proximity: 0.8081
# Epoch 4/10
# 16/16 [==============================] - 0s 915us/step - loss: 31.8258 - cosine_proximity: 0.8081
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 26.6175 - cosine_proximity: 0.8081
# Epoch 6/10
# 16/16 [==============================] - 0s 972us/step - loss: 22.2073 - cosine_proximity: 0.8081
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 18.4867 - cosine_proximity: 0.8081
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 15.3962 - cosine_proximity: 0.8081
# Epoch 9/10
# ...
